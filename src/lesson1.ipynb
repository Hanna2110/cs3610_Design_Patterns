# %% [markdown]
# **Installing Python**

# %% [markdown]
# First, check whether Python is installed on your system. Open a command window by entering command into the *Start menu* and clicking the *Command Prompt* app.
# In the terminal window, enter *python* in lowercase. If you get a Python prompt (>>>) in response, Python is installed on your system

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If Python is not installed on your system, or if you see a version earlier than Python 3.9, you need to download a Python installer.
# Go to https://python.org

# %% [markdown]
# Make sure you select the option Add Python to PATH, which will make it easier to configure your system correctly

# %% [markdown]
# **Installing Essential VSCode Python Extensions**

# %% [markdown]
# https://www.datacamp.com/tutorial/setting-up-vscode-python

# %% [markdown]
# Select the Python Interpreter:
#
# Press Shift + Control + P to open the Command Palette and click on the Python: Select Interpreter
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Steps to create virtual environment:
#
# 1. go to folder containing project
# 2. Open a powershell terminal within VSCode and use the command
#
# *python -m venv .venv* to create a virtual environment.
#
# Attach this virtual environment to your workspace
#
# OR
#
# Press *Shift + Control + P* to open the Command Palette and click on the following:
#
# ![image.png](attachment:image.png)
#
# ![   ](attachment:image-2.png)
#
# 3. Activate your virtualenv
#
# .\\.venv\Scripts\activate
#
# ![image-3.png](attachment:image-3.png)
#
# 4. Now you can install required libraries in virtual environment (e.g., *pip install sklearn*)
# 5. To keep track of what is installed:
#
# *pip freeze > requirements.txt*
#
# After this you will be able to install those required libraries in any (new) virtual environment:
#
# *pip3 install -r requirement.txt*
#
# And, if needed restart VS code editor
#
#
#
# to stop working in virtual environment type: *deactivate*
#
# to remove virtual environment type: *rm -rf evn_name*
#
# For the older versions of VSCode you may also need to do the following:
#
# Then Python: Select Interpreter (via Ctrl + Shift + P)
#
# And select the option:
#
# ![image-4.png](attachment:image-4.png)
