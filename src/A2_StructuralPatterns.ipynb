# %% [markdown]
# # Design Patterns Module - Assignment 2. Structural Patterns

# %% [markdown]
# ## Task 1. Adapter

# %% [markdown]
# Suppose we are developing a climate control system designed to automatically maintain the temperature of the surrounding space accordingly to weather forcast.​
#
# An important component of such a system is a Weather Forcasting Sensor, which measures the ambient temperature for subsequent analysis and futher forcast.​
#
# Your App collects weather data from several sensors in binary format.
#
# The App displays this data on its interface.
#
# You have decided to add a third-party library to improve forecasting accuracy.
#
# ![image.png](attachment:image.png)
#
# However, you cannot use this class directly, since the library only accepts data in XML.
#
#
# ![image-2.png](attachment:image-2.png)
#
# 1. Design UML Class Diagram
# 2. Implement the App by using the Adapter pattern

# %% [markdown]
# ## Task 2.
